# %% [markdown]
# ## Algebra Lineal Cuántica
#
# https://quantum.microsoft.com/en-us/tools/quantum-katas
#
#
# https://chatgpt.com/c/68bc04de-8668-8331-9cfb-2777d52ba085

# %%
# %pip install sympy --upgrade
# Out:
# Requirement already satisfied: sympy in /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages (from sympy) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip uninstall sympy
# Out:
# Found existing installation: sympy 1.14.0
# Uninstalling sympy-1.14.0:
#   Would remove:
#     /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/bin/isympy
#     /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages/isympy.py
#     /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages/sympy-1.14.0.dist-info/*
#     /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/lib/python3.13/site-packages/sympy/*
#     /home/miguel/miniconda3/envs/CondaCodingQiskitEnvironment/share/man/man1/isympy.1
# Proceed (Y/n)? ERROR: Operation cancelled by user
# ^C
# Note: you may need to restart the kernel to use updated packages.
