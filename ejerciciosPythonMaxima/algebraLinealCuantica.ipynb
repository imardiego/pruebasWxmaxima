# %% [markdown]
# ## Algebra Lineal Cuántica
#
# https://quantum.microsoft.com/en-us/tools/quantum-katas

# %% [markdown]
# En el fichero:
#
#     -  ejecucionMaximafromPython.ipynb
#
# valoramos distintos sistemas para ejecutar comandos desde python hacia maxima.
#
# Sistemas recomendados:
#
#     - como subproceso
#
#     - mediante una función mágica
